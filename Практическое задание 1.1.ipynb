# %% [markdown]
# ## Практическое задание 1.1

# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$
#
# __Решение__
# Заметим, что $f_{4}(x)=f_{3}(x)-f_{2}(x)-f_{1}(x)$, то есть вектор $f_{4}(x)$ — линейная комбинация векторов $f_{3}(x), f_{2}(x)$ и $f_{1}(x)$, из чего можно сделать вывод, что $f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}$ линейно зависимы.

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# __Решение__
# Заметим, что $f_{4}(x)=f_{3}(x)+2f_{2}(x)+0,5f_{1}(x)$, то есть вектор $f_{4}(x)$ — линейная комбинация векторов $f_{3}(x), f_{2}(x)$ и $f_{1}(x)$, из чего можно сделать вывод, что $f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$ линейно зависимы.

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# __Решение__
#
# Видим, что базис линейного пространства $\mathbb{R}^{3}$ образуют векторы
# $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.
# Тогда
#
# $$x=(2, 3, 5)=(2,0,0)+(0, 3, 0)+(0, 0, 5)=0,5\cdot(0, 0, 10) + 1\cdot(2, 0, 0)+3\cdot(0, 1, 0)=0,5b_{1} + b_{2}+3b_{3}$$
#
#
# то есть координатами вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$ являются $0.5$, $1$, $3$.

# %% [markdown]
# ##__4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;

# %% [markdown]
# __Решение__
# Вектор $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ можно представить как $x = (3, -2, 2)$
# Видим, что базис линейного пространства $\mathbb{R}^{3}[x]$ образуют векторы
# $b_{1}=(0, 0, 1)$, $b_{2}=(0, 1, 0)$, $b_{3}=(1, 0, 0)$.
# Тогда
#
# $$x=(3, -2, 2)=(3,0,0)+(0, -2, 0)+(0, 0, 2)=2\cdot(0, 0, 1) + (-2)\cdot(0, 1, 0)+3\cdot(1, 0, 0)=2b_{1} + (-2)\cdot b_{2}+3 \cdot b_{3}$$
#
#
# то есть координатами вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ в базисе $1$, $x$, $x^{2}$ являются $2$, $-2$, $3$.

# %% [markdown]
# б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# __Решение__
# Вектор $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ можно представить как $x = (3, -2, 2)$
# Видим, что базис линейного пространства $\mathbb{R}^{3}[x]$ образуют векторы
# $b_{1}=(1, 0, 0)$, $b_{2}=(0, 1, -1)$, $b_{3}=(0, 0, 1)$.
# Тогда
#
# $$x=(3, -2, 2)=a_1\cdot(1, 0, 0) + a_2\cdot(0, 1, -1)+a_3\cdot(0, 0, 1)$$
# Из данного равенства получаем систему уравнений  и решаем ее:
#
# ### \begin{cases}
#     a_1 \cdot 1 + a_2 \cdot 0 + a_3 \cdot 0 = 3\\
#    a_1 \cdot 0 + a_2 \cdot 1 + a_3\cdot 0 = -2\\
#    a_1 \cdot 0 - a_2 \cdot 1 + a_3 \cdot 1 = 2
#    \end{cases}
#
# Решая данную систему, получаем, что координатами вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$ в базисе $1$, $x$, $x^{2}$ являются $3$, $-2$, $0$.

# %% [markdown]
# ##__5.__ Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю
#
#
# Помним ,что подмножество $L$ линейного пространства $V$ является его подпространством тогда и только тогда, когда для любых элементов $u, v\in L$ и любого $\alpha \in \mathbb{R}$ выполняются условия:
#
# $$1)\ u+v\in L;$$
#
# $$2)\ \alpha\cdot u \in L.$$
#
# __Решение:__
# Проведем проверку по выше приведенному утверждению
#
# $$(0, b, c)+(a, 0, c) = (a, b, c+с),$$ $$\alpha\cdot (0, b, с) = (0, \alpha b, \alpha с).$$
#
#
# Из полученных векторов первый не принадлежат указанному в задании множеству всех векторов вида $(0, b, c)$ или $(a, 0, c)$, то есть данное множество не является подпространством линейного пространства $\mathbb{R}^{3}$.

# %% [markdown]
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$.
#
#
# __Решение:__
# Проведем проверку по выше приведенному утверждению
#
# $$(a_1u_1 + a_2u_2 +...+a_nu_n)+(b_1u_1 + b_2u_2 +...+b_nu_n) = ((a_1+b_1)u_1, (a_2+b_2)u_2, ...,(a_n+b_n)u_n),$$ $$\alpha\cdot (a_1u_1 + a_2u_2 +...+a_nu_n) = (\alpha a_1u_1, \alpha a_2u_2, ...,  \alpha a_nu_n).$$
# И вектор $((a_1+b_1)u_1, (a_2+b_2)u_2, ...,(a_n+b_n)u_n)$, и вектор $(\alpha a_1u_1, \alpha a_2u_2, ...,  \alpha a_nu_n)$  все еще являяются элементами подмножества линейных комбинаций векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$. Следовательно, множество всех векторов, являющихся линейными комбинациями векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$ является является его линейным подпространством.
